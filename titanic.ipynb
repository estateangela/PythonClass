# %% [markdown]
# <a href="https://colab.research.google.com/github/estateangela/PythonClass/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(8)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 51            52         0       3             Nosworthy, Mr. Richard Cater
# 504          505         1       1                    Maioni, Miss. Roberta
# 736          737         0       3  Ford, Mrs. Edward (Margaret Ann Watson)
# 729          730         0       3            Ilmakangas, Miss. Pieta Sofia
# 499          500         0       3                       Svensson, Mr. Olof
# 242          243         0       2          Coleridge, Mr. Reginald Charles
# 601          602         0       3                     Slabenoff, Mr. Petco
# 691          692         1       3                       Karun, Miss. Manca
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 51     male  21.0      0      0        A/4. 39886   7.8000   NaN        S
# 504  female  16.0      0      0            110152  86.5000   B79        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().any(axis=1).sum()
# Out:
# 708

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].fillna(value=df['Age'].mean(),inplace=True)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df.iloc[59:63]
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 60           61         0       3               Sirayanian, Mr. Orsen    male
# 61           62         1       1                 Icard, Miss. Amelie  female
# 62           63         0       1         Harris, Mr. Henry Birkhardt    male
#
#      Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 59  11.0      5      2  CA 2144  46.9000   NaN        S
# 60  22.0      0      0     2669   7.2292   NaN        C
# 61  38.0      0      0   113572  80.0000   B28      NaN
# 62  45.0      1      0    36973  83.4750   C83        S

# %%
df_temp = df['Embarked'].fillna(method='bfill',inplace=True)

# %%
df.iloc[59:63]
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 60           61         0       3               Sirayanian, Mr. Orsen    male
# 61           62         1       1                 Icard, Miss. Amelie  female
# 62           63         0       1         Harris, Mr. Henry Birkhardt    male
#
#      Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 59  11.0      5      2  CA 2144  46.9000   NaN        S
# 60  22.0      0      0     2669   7.2292   NaN        C
# 61  38.0      0      0   113572  80.0000   B28        S
# 62  45.0      1      0    36973  83.4750   C83        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df['Sex'].unique(), df['Sex'].nunique()
# Out:
# (array(['male', 'female'], dtype=object), 2)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.sort_values(by='Embarked').head()
# Out:
#      PassengerId  Survived  Pclass  \
# 215          216         1       1
# 111          112         0       3
# 367          368         1       3
# 366          367         1       1
# 114          115         0       3
#
#                                                  Name     Sex        Age  \
# 215                           Newell, Miss. Madeleine  female  31.000000
# 111                              Zabour, Miss. Hileni  female  14.500000
# 367                    Moussa, Mrs. (Mantoura Boulos)  female  29.699118
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.000000
# 114                             Attalah, Miss. Malake  female  17.000000
#
#      SibSp  Parch  Ticket      Fare Embarked
# 215      1      0   35273  113.2750        C
# 111      1      0    2665   14.4542        C
# 367      0      0    2626    7.2292        C
# 366      1      0  110813   75.2500        C
# 114      0      0    2627   14.4583        C

# %%
df.reset_index(inplace=True)
df.set_index('PassengerId',inplace=True)
df
# Out:
#              level_0  index  Survived  Pclass  \
# PassengerId
# 1                  0      0         0       3
# 2                  1      1         1       1
# 3                  2      2         1       3
# 4                  3      3         1       1
# 5                  4      4         0       3
# ...              ...    ...       ...     ...
# 887              886    886         0       2
# 888              887    887         1       1
# 889              888    888         0       3
# 890              889    889         1       1
# 891              890    890         0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# ...

# %%
df.to_csv('result.csv')
